# %% [markdown]
# # Speech Understanding
# # Lecture 12: Text-to-Speech Synthesis

# %% [markdown]
# ### Mark Hasegawa-Johnson, KCGI

# %% [markdown]
# 1. <a href="#section1">Installing gTTs, the Google speech synthesizer</a>
# 1. <a href="#section2">Using gTTs</a>
# 1. <a href="#section3">Use SpeechRecognizer to check the output</a>
# 1. <a href="#section4">Create an electronic parrot</a>
# 1. <a href="#homework">Homework</a>

# %% [markdown]
# <a id='section1'></a>

# %% [markdown]
# ## 1. Installing gTTs, the Google speech synthesizer

# %% [markdown]
# For speech synthesis, we will use Google's text-to-speech synthesis system (gTTs).  You need to be connected to the internet in order to use it. Documentation for gTTs is here: https://gtts.readthedocs.io/en/latest/
#
# gTTs is installed like this (either in the window below, or in a terminal):

# %%
# !pip install gTTs -i https://mirror.baidu.com/pypi/simple
# Out:
# Looking in indexes: https://mirror.baidu.com/pypi/simple
# Requirement already satisfied: gTTs in f:\python\lib\site-packages (2.5.0)
# Requirement already satisfied: requests<3,>=2.27 in f:\python\lib\site-packages (from gTTs) (2.31.0)
# Requirement already satisfied: click<8.2,>=7.1 in f:\python\lib\site-packages (from gTTs) (8.0.3)
# Requirement already satisfied: colorama in f:\python\lib\site-packages (from click<8.2,>=7.1->gTTs) (0.4.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in f:\python\lib\site-packages (from requests<3,>=2.27->gTTs) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in f:\python\lib\site-packages (from requests<3,>=2.27->gTTs) (3.2)
# Requirement already satisfied: certifi>=2017.4.17 in f:\python\lib\site-packages (from requests<3,>=2.27->gTTs) (2023.11.17)
# Requirement already satisfied: urllib3<3,>=1.21.1 in f:\python\lib\site-packages (from requests<3,>=2.27->gTTs) (1.26.7)

# %%
# !pip install numba==0.56.4 -i https://mirror.baidu.com/pypi/simple --user
# !pip install librosa==0.9.1 -i https://mirror.baidu.com/pypi/simple --user
# Out:
# Looking in indexes: https://mirror.baidu.com/pypi/simple
# Requirement already satisfied: numba==0.56.4 in c:\users\hp\appdata\roaming\python\python39\site-packages (0.56.4)
# Requirement already satisfied: setuptools in f:\python\lib\site-packages (from numba==0.56.4) (58.0.4)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in c:\users\hp\appdata\roaming\python\python39\site-packages (from numba==0.56.4) (0.39.1)
# Requirement already satisfied: numpy<1.24,>=1.18 in f:\python\lib\site-packages (from numba==0.56.4) (1.20.3)
# Looking in indexes: https://mirror.baidu.com/pypi/simple
# Requirement already satisfied: librosa==0.9.1 in c:\users\hp\appdata\roaming\python\python39\site-packages (0.9.1)
# Requirement already satisfied: numpy>=1.17.0 in f:\python\lib\site-packages (from librosa==0.9.1) (1.20.3)
# Requirement already satisfied: joblib>=0.14 in f:\python\lib\site-packages (from librosa==0.9.1) (1.1.0)
# Requirement already satisfied: audioread>=2.1.5 in f:\python\lib\site-packages (from librosa==0.9.1) (3.0.1)
# Requirement already satisfied: decorator>=4.0.10 in f:\python\lib\site-packages (from librosa==0.9.1) (5.1.0)
# Requirement already satisfied: scipy>=1.2.0 in f:\python\lib\site-packages (from librosa==0.9.1) (1.7.1)
# Requirement already satisfied: pooch>=1.0 in f:\python\lib\site-packages (from librosa==0.9.1) (1.8.0)
# Requirement already satisfied: scikit-learn>=0.19.1 in f:\python\lib\site-packages (from librosa==0.9.1) (0.24.2)
# Requirement already satisfied: numba>=0.45.1 in c:\users\hp\appdata\roaming\python\python39\site-packages (from librosa==0.9.1) (0.56.4)
# Requirement already satisfied: packaging>=20.0 in f:\python\lib\site-packages (from librosa==0.9.1) (21.0)
# Requirement already satisfied: resampy>=0.2.2 in f:\python\lib\site-packages (from librosa==0.9.1) (0.4.2)
# Requirement already satisfied: soundfile>=0.10.2 in f:\python\lib\site-packages (from librosa==0.9.1) (0.12.1)
# Requirement already satisfied: setuptools in f:\python\lib\site-packages (from numba>=0.45.1->librosa==0.9.1) (58.0.4)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in c:\users\hp\appdata\roaming\python\python39\site-packages (from numba>=0.45.1->librosa==0.9.1) (0.39.1)
# Requirement already satisfied: pyparsing>=2.0.2 in f:\python\lib\site-packages (from packaging>=20.0->librosa==0.9.1) (3.0.4)
# Requirement already satisfied: platformdirs>=2.5.0 in f:\python\lib\site-packages (from pooch>=1.0->librosa==0.9.1) (4.1.0)
# Requirement already satisfied: requests>=2.19.0 in f:\python\lib\site-packages (from pooch>=1.0->librosa==0.9.1) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in f:\python\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa==0.9.1) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in f:\python\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa==0.9.1) (2023.11.17)
# Requirement already satisfied: urllib3<3,>=1.21.1 in f:\python\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa==0.9.1) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5 in f:\python\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa==0.9.1) (3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in f:\python\lib\site-packages (from scikit-learn>=0.19.1->librosa==0.9.1) (2.2.0)
# Requirement already satisfied: cffi>=1.0 in f:\python\lib\site-packages (from soundfile>=0.10.2->librosa==0.9.1) (1.14.6)
# Requirement already satisfied: pycparser in f:\python\lib\site-packages (from cffi>=1.0->soundfile>=0.10.2->librosa==0.9.1) (2.20)

# %% [markdown]
# <a id="section2"></a>

# %% [markdown]
# ## 2. Using gTTs

# %% [markdown]
# gTTs can't play the audio directly.  We need to create the audio output, save it to a file, and then play back the file.

# %%
import gtts, librosa, IPython

desired_text = "これは合成音声です"
tts = gtts.gTTS(text=desired_text, lang="ja")
tts.save("speech.mp3")
    
speech_wave, speech_rate = librosa.load("speech.mp3")
IPython.display.Audio(data=speech_wave, rate=speech_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# The `wb` modifier in `open` is important.  It specifies that the file is
# * binary (`b`)
# * writable (`w`)

# %% [markdown]
# <a id="section3"></a>

# %% [markdown]
# ## 3. Use SpeechRecognizer to check the output
#
# Often, in the real world, you need to generate synthetic speech prompts for a customer, but you don't have time to listen to all of them to make sure they're OK.
#
# When that happens, you can use `SpeechRecognizer` to check each of the files automatically.  If `SpeechRecognizer` detects any mistake, you can check manually to see if it's OK.
#
# First, we need to convert the file from `mp3` format to a format that `SpeechRecognizer` can handle.  `SpeechRecognizer` can handle wav and flac files.  We can use librosa to read in the mp3, then use soundfile to write it out, as shown [here](https://librosa.org/doc/main/ioformats.html#write-out-audio-files).

# %%
# !pip install soundfile
# Out:
# Requirement already satisfied: soundfile in f:\python\lib\site-packages (0.12.1)
# Requirement already satisfied: cffi>=1.0 in f:\python\lib\site-packages (from soundfile) (1.14.6)
# Requirement already satisfied: pycparser in f:\python\lib\site-packages (from cffi>=1.0->soundfile) (2.20)

# %%
import librosa, soundfile
data, samplerate = librosa.load('speech.mp3')
soundfile.write('speech.wav',data,samplerate)

# %% [markdown]
# Now we can call `speech_recognition` to check the file content:

# %%
import speech_recognition

r = speech_recognition.Recognizer()

with speech_recognition.AudioFile("speech.wav") as source:
    audio = r.record(source)
    text = r.recognize_google(audio, language="ja")
    print('The person in this audio file said "%s"'%(text))
    if text == desired_text:
        print('This matches the desired text')
    else:
        print('This does not match the desired text, which was "%s"'%(desired_text))
# Out:
# The person in this audio file said "これは 合成音声です"
# This does not match the desired text, which was "これは合成音声です"

# %% [markdown]
# <a id='section4'></a>

# %% [markdown]
# ## 4. Create an electronic parrot

# %% [markdown]
# Now that we have both speech input and speech output, let's create our first speech app!
#
# This app will just be an electronic parrot.  The electronic parrot will listen to what you say, and try to repeat it.

# %%
import speech_recognition, gtts, IPython, librosa

def electronic_parrot():
    print("Hello!  I'm an electronic parrot 🦜.")
    print("Please say something, and I will try to repeat it.")
    
    r = speech_recognition.Recognizer()

    while True:
        with speech_recognition.Microphone() as source:
            print("Listening...")
            r.adjust_for_ambient_noise(source)
            try:
                audio = r.listen(source)
                text = r.recognize_google(audio, language='en')
            except speech_recognition.UnknownValueError:
                print('I did not understand that, I will try again')
                continue
            except sr.RequestError:
                print('Sorry, I could not reach the internet, I will try again')
                continue
            except sr.WaitTimeoutError:
                continue
            break
            
    print('I heard you say "%s", and now I will try to repeat it'%(text))
    gtts.gTTS(text='You said "%s"'%(text), lang="en").save("parrot.mp3")
    speech_wave, speech_rate = librosa.load("parrot.mp3")
    return IPython.display.Audio(data=speech_wave, rate=speech_rate)

# %%
# !pip install pipwin
# !pipwin install PyAudio
# Out:
# Collecting pipwin
#   Downloading pipwin-0.5.2.tar.gz (7.9 kB)
# Collecting docopt
#   Downloading docopt-0.6.2.tar.gz (25 kB)
# Requirement already satisfied: requests in f:\python\lib\site-packages (from pipwin) (2.31.0)
# Collecting pyprind
#   Downloading PyPrind-2.11.3-py2.py3-none-any.whl (8.4 kB)
# Requirement already satisfied: six in f:\python\lib\site-packages (from pipwin) (1.16.0)
# Requirement already satisfied: beautifulsoup4>=4.9.0 in f:\python\lib\site-packages (from pipwin) (4.10.0)
# Collecting js2py
#   Downloading Js2Py-0.74-py3-none-any.whl (1.0 MB)
# Requirement already satisfied: packaging in f:\python\lib\site-packages (from pipwin) (21.0)
# Collecting pySmartDL>=1.3.1
#   Downloading pySmartDL-1.3.4-py3-none-any.whl (20 kB)
# Requirement already satisfied: soupsieve>1.2 in f:\python\lib\site-packages (from beautifulsoup4>=4.9.0->pipwin) (2.2.1)
# Collecting pyjsparser>=2.5.1
#   Downloading pyjsparser-2.7.1.tar.gz (24 kB)
# Collecting tzlocal>=1.2
#   Downloading tzlocal-5.2-py3-none-any.whl (17 kB)
# Collecting tzdata
#   Downloading tzdata-2023.4-py2.py3-none-any.whl (346 kB)
# Requirement already satisfied: pyparsing>=2.0.2 in f:\python\lib\site-packages (from packaging->pipwin) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in f:\python\lib\site-packages (from requests->pipwin) (2023.11.17)
# Requirement already satisfied: urllib3<3,>=1.21.1 in f:\python\lib\site-packages (from requests->pipwin) (1.26.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in f:\python\lib\site-packages (from requests->pipwin) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in f:\python\lib\site-packages (from requests->pipwin) (3.2)
# Building wheels for collected packages: pipwin, docopt, pyjsparser
#   Building wheel for pipwin (setup.py): started
#   Building wheel for pipwin (setup.py): finished with status 'done'
#   Created wheel for pipwin: filename=pipwin-0.5.2-py2.py3-none-any.whl size=8790 sha256=6ec79c18bab6884529e718301b8e70c762ec373da8380ed2bd3fd87e7c746d89
#   Stored in directory: c:\users\hp\appdata\local\pip\cache\wheels\bc\86\30\f70db104d3f51560d9a177d6ced4f7e09f3e474d6985c101ae
#   Building wheel for docopt (setup.py): started
#   Building wheel for docopt (setup.py): finished with status 'done'
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13724 sha256=a7a49c96efebf8fb44ed0213d9e934363f34a41026df6fca9aeba6b85e2e2ffd
#   Stored in directory: c:\users\hp\appdata\local\pip\cache\wheels\70\4a\46\1309fc853b8d395e60bafaf1b6df7845bdd82c95fd59dd8d2b
#   Building wheel for pyjsparser (setup.py): started
#   Building wheel for pyjsparser (setup.py): finished with status 'done'
#   Created wheel for pyjsparser: filename=pyjsparser-2.7.1-py3-none-any.whl size=26001 sha256=43a787b8a850d8278ca97d536bb245afcf9f1c9bc9c3f2002c623c0601509601
#   Stored in directory: c:\users\hp\appdata\local\pip\cache\wheels\f0\70\61\f42dc45dcf0fbe8c495ce579b04730787081499bfb5b8bc60e
# Successfully built pipwin docopt pyjsparser
# Installing collected packages: tzdata, tzlocal, pyjsparser, pySmartDL, pyprind, js2py, docopt, pipwin
# Successfully installed docopt-0.6.2 js2py-0.74 pipwin-0.5.2 pySmartDL-1.3.4 pyjsparser-2.7.1 pyprind-2.11.3 tzdata-2023.4 tzlocal-5.2
# Building cache. Hang on . . .
# Done
# Package `pyaudio` found in cache
# Downloading package . . .
# https://download.lfd.uci.edu/pythonlibs/archived/PyAudio-0.2.11-cp39-cp39-win_amd64.whl
# PyAudio-0.2.11-cp39-cp39-win_amd64.whl
# [*] 0 bytes / 111 kB @ 0 bytes/s [------------------] [0.0%, 0s left]   [*] 0 bytes / 111 kB @ 0 bytes/s [------------------] [0.0%, 0s left]   [*] 0 bytes / 111 kB @ 0 bytes/s [------------------] [0.0%, 0s left]   [*] 0 bytes / 111 kB @ 0 bytes/s [------------------] [0.0%, 0s left]   [*] 0 bytes / 111 kB @ 0 bytes/s [------------------] [0.0%, 0s left]   [*] 0 bytes / 111 kB @ 0 bytes/s [------------------] [0.0%, 0s left]   [*] 8 kB / 111 kB @ 11 kB/s [#-----------------] [7.2%, 0s left]  [*] 40 kB / 111 kB @ 50 kB/s [######------------] [36.0%, 0s left]  [*] 40 kB / 111 kB @ 44 kB/s [######------------] [36.0%, 0s left]  Processing c:\users\hp\pipwin\pyaudio-0.2.11-cp39-cp39-win_amd64.whl
# Installing collected packages: PyAudio
# Successfully installed PyAudio-0.2.11
# [*] 111 kB / 111 kB @ 44 kB/s [##################] [100%, 0s left]

# %%
electronic_parrot()
# Out:
# Hello!  I'm an electronic parrot 🦜.
# Please say something, and I will try to repeat it.
# Listening...
# I did not understand that, I will try again
# Listening...
# I did not understand that, I will try again
# Listening...
# I did not understand that, I will try again
# Listening...
# I did not understand that, I will try again
# Listening...
# I did not understand that, I will try again
# Listening...
# I did not understand that, I will try again
# Listening...
# I did not understand that, I will try again
# Listening...
# I did not understand that, I will try again
# Listening...
# I heard you say "turn off", and now I will try to repeat it
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# <a id='homework'></a>

# %% [markdown]
# ## Homework

# %% [markdown]
# Edit the text file called `homework12.py`.
#
# This file should `def` a function called `synthesize`, with a signature as shown here:

# %%
import homework12, importlib
importlib.reload(homework12)
help(homework12.synthesize)
# Out:
# Help on function synthesize in module homework12:
#
# synthesize(text, lang, filename)
#     Use gtts.gTTs(text=text, lang=lang) to synthesize speech, then write it to filename.
#
#     @params:
#     text (str) - the text you want to synthesize
#     lang (str) - the language in which you want to synthesize it
#     filename (str) - the filename in which it should be saved

# %% [markdown]
# Test whether your code works by running the following block:

# %%
import homework12, librosa, IPython, importlib
importlib.reload(homework12)

homework12.synthesize("This is speech synthesis!","en","english.mp3")
y, sr = librosa.load("english.mp3")
IPython.display.Audio(data=y, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### Receiving your grade
#
# In order to receive a grade for your homework, you need to:
#
# 1. Run the following code block on your machine.  The result may list some errors, and then in the very last line, it will show a score.  That score (between 0% and 100%) is the grade you have earned so far.  If you want to earn a higher grade, please continue editing `homework3.py`, and then run this code block again.
# 1. When you are happy with your score (e.g., when it reaches 100%), choose `File` $\Rightarrow$ `Save and Checkpoint`.  Then use `GitHub Desktop` to commit and push your changes.
# 1. Make sure that the 100% shows on your github repo on github.com.  If it doesn't, you will not receive credit.

# %%
import importlib, grade
importlib.reload(grade)
# Out:
# .F..
# 3 successes out of 4 tests run
# Score: 75%
# ======================================================================
# FAIL: test_method_creates_correct_synthesis_spanish (grade.Test)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "F:\Jupyter-notebook\github\intro_speech_understanding\2023_fall\lec12\grade.py", line 63, in test_method_creates_correct_synthesis_spanish
#     self.assertEqual(int(len(hypothesis)/1024), int(len(reference)/1024),
# AssertionError: 9 != 8 :
#                          homework12.synthesize, when called with a non-English text string,
#                          creates a file with the wrong content.
#
#
# ----------------------------------------------------------------------
# Ran 4 tests in 0.797s
#
# FAILED (failures=1)
# <module 'grade' from 'F:\\Jupyter-notebook\\github\\intro_speech_understanding\\2023_fall\\lec12\\grade.py'>
